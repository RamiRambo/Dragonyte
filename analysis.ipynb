# %%
import pandas as pd
import numpy as np

# %%
chan = pd.read_csv('clean_channels.csv')

# %%
chan['Hierarchy_Level'].unique()
# Out:
# array([1])

# %%
channel_volume_or = pd.read_csv('Untouched_Business_case/Data/Channel_Volume.csv', delimiter=',')

# %%
channel_volume_or
# Out:
#       Location          Industry  Edition Category Subcategory  \
# 0            1  Alcoholic Drinks     2022     Beer        Beer
# 1            1  Alcoholic Drinks     2022     Beer        Beer
# 2            1  Alcoholic Drinks     2022     Beer        Beer
# 3            1  Alcoholic Drinks     2022     Beer        Beer
# 4            1  Alcoholic Drinks     2022     Beer        Beer
# ...        ...               ...      ...      ...         ...
# 8463         7  Alcoholic Drinks     2022     Beer        Beer
# 8464         7  Alcoholic Drinks     2022     Beer        Beer
# 8465         7  Alcoholic Drinks     2022     Beer        Beer
# 8466         7  Alcoholic Drinks     2022     Beer        Beer
# 8467         7  Alcoholic Drinks     2022     Beer        Beer
#
#       Hierarchy_Level         Data_Type                          Outlet  \
# 0                   1  Off-trade Volume  Food/drink/tobacco specialists
# ...

# %%
market_df = pd.read_csv('market_size_cleaned.csv')

# %%
market_df
# Out:
#       Unnamed: 0  Location          Industry  Subcategory  Hierarchy_Level  \
# 0              0         1  Alcoholic Drinks            1                3
# 1              1         1  Alcoholic Drinks            1                3
# 2              2         1  Alcoholic Drinks            1                3
# 3              3         1  Alcoholic Drinks            1                3
# 4              4         1  Alcoholic Drinks            1                3
# ...          ...       ...               ...          ...              ...
# 1216        1216         7  Alcoholic Drinks           17                1
# 1217        1217         7  Alcoholic Drinks           17                1
# 1218        1218         7  Alcoholic Drinks           17                1
# 1219        1219         7  Alcoholic Drinks           17                1
# 1220        1220         7  Alcoholic Drinks           17                1
#
#             Data_Type         Unit  \
# ...

# %%
market_df['Year'].unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026])
