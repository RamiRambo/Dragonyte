# %%
import pandas as pd
import numpy as np

# %%
channel_volume = pd.read_csv('Untouched_Business_case/Data/Channel_Volume.csv')
company_share = pd.read_csv('Untouched_Business_case/Data/Company_Share_GBO_unit.csv', delimiter=';')
location = pd.read_csv('Untouched_Business_case/Data/Locations.csv', delimiter=';').T
market_size = pd.read_csv('Untouched_Business_case/Data/Market_Sizes.csv')
subcategories = pd.read_csv('Untouched_Business_case/Data/Subcategories.csv')

# %% [markdown]
# CHANNEL VOLUME

# %%
channel_volume.head()
# Out:
#    Location          Industry  Edition Category Subcategory  Hierarchy_Level  \
# 0         1  Alcoholic Drinks     2022     Beer        Beer                1
# 1         1  Alcoholic Drinks     2022     Beer        Beer                1
# 2         1  Alcoholic Drinks     2022     Beer        Beer                1
# 3         1  Alcoholic Drinks     2022     Beer        Beer                1
# 4         1  Alcoholic Drinks     2022     Beer        Beer                1
#
#           Data_Type                          Outlet  Outlet_Hierarchy  \
# 0  Off-trade Volume  Food/drink/tobacco specialists                 3
# 1  Off-trade Volume  Food/drink/tobacco specialists                 3
# 2  Off-trade Volume  Food/drink/tobacco specialists                 3
# 3  Off-trade Volume  Food/drink/tobacco specialists                 3
# 4  Off-trade Volume  Food/drink/tobacco specialists                 3
#
#              Unit  Year_text                    Year_date       Volume
# 0  million litres       2007     Monday, 31 December 2007  2613,845506
# 1  million litres       2008  Wednesday, 31 December 2008  2513,025824
# 2  million litres       2009   Thursday, 31 December 2009  2421,088595
# 3  million litres       2010     Friday, 31 December 2010  2422,128432
# 4  million litres       2011   Saturday, 31 December 2011   2439,33622

# %%
channel_volume.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8468 entries, 0 to 8467
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          8468 non-null   int64
#  1   Industry          8468 non-null   object
#  2   Edition           8468 non-null   int64
#  3   Category          8464 non-null   object
#  4   Subcategory       8468 non-null   object
#  5   Hierarchy_Level   8468 non-null   int64
#  6   Data_Type         8468 non-null   object
#  7   Outlet            8468 non-null   object
#  8   Outlet_Hierarchy  8468 non-null   int64
#  9   Unit              8468 non-null   object
#  10  Year_text         8468 non-null   int64
#  11  Year_date         8468 non-null   object
#  12  Volume            8468 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 860.2+ KB

# %%
channel_volume['Year_date'].unique()
# Out:
# array(['Monday, 31 December 2007', 'Wednesday, 31 December 2008',
#        'Thursday, 31 December 2009', 'Friday, 31 December 2010',
#        'Saturday, 31 December 2011', 'Monday, 31 December 2012',
#        'Tuesday, 31 December 2013', 'Wednesday, 31 December 2014',
#        'Thursday, 31 December 2015', 'Saturday, 31 December 2016',
#        'Sunday, 31 December 2017', 'Monday, 31 December 2018',
#        'Tuesday, 31 December 2019', 'Thursday, 31 December 2020',
#        'Friday, 31 December 2021'], dtype=object)

# %%
channel_volume['Category'].unique()
# Out:
# array(['Beer', 'Cider/Perry', 'RTDs/High-Strength Premixes', 'Spirits',
#        'Wine', nan], dtype=object)

# %%
channel_volume.loc[channel_volume['Category'].isnull() == True]
# Out:
#       Location          Industry  Edition Category  Subcategory  \
# 603          6  Alcoholic Drinks     2022      NaN         Wine
# 1974         3  Alcoholic Drinks     2022      NaN         Beer
# 2986         5  Alcoholic Drinks     2022      NaN  Cider/Perry
# 7547         5  Alcoholic Drinks     2022      NaN  Cider/Perry
#
#       Hierarchy_Level         Data_Type                   Outlet  \
# 603                 1  Off-trade Volume  Small Grocery Retailers
# 1974                1  Off-trade Volume             Hypermarkets
# 2986                1  Off-trade Volume          Warehouse Clubs
# 7547                1  Off-trade Volume      Non-Store Retailing
#
#       Outlet_Hierarchy            Unit  Year_text                  Year_date  \
# 603                  3  million litres       2010   Friday, 31 December 2010
# 1974                 3  million litres       2019  Tuesday, 31 December 2019
# 2986                 3      000 litres       2010   Friday, 31 December 2010
# 7547                 1      000 litres       2017   Sunday, 31 December 2017
#
#            Volume
# 603   120,5453744
# 1974  2353,577788
# 2986  7,811885045
# 7547  0,028513974

# %% [markdown]
# LOCATION

# %%
location
# Out:
#                           0                       1
# id                   Region                 Country
# 0                       NaN                     NaN
# 1              Asia Pacific            Asia Pacific
# 0.1                     NaN                     NaN
# 2               Australasia             Australasia
# 0.2                     NaN                     NaN
# 3            Eastern Europe          Eastern Europe
# 0.3                     NaN                     NaN
# 4             Latin America           Latin America
# 0.4                     NaN                     NaN
# 5    Middle East and Africa  Middle East and Africa
# 0.5                     NaN                     NaN
# 6             North America           North America
# 0.6                     NaN                     NaN
# 7            Western Europe          Western Europe
# 0.7                     NaN                     NaN
# 8                     World                   World
# 0.8                     NaN                     NaN

# %%
location = location.dropna()
location.columns = location.iloc[0]
location = location.tail(-1)
location
# Out:
# id                  Region                 Country
# 1             Asia Pacific            Asia Pacific
# 2              Australasia             Australasia
# 3           Eastern Europe          Eastern Europe
# 4            Latin America           Latin America
# 5   Middle East and Africa  Middle East and Africa
# 6            North America           North America
# 7           Western Europe          Western Europe
# 8                    World                   World

# %%
location.to_csv('location_cleaned.csv', index=False)

# %% [markdown]
# COMPANY SHARE

# %%
company_share
# Out:
#        Location          Industry  Subcategory_ID  Hierarchy_Level  \
# 0           NaN               NaN             NaN              NaN
# 1           8.0  Alcoholic Drinks            13.0              1.0
# 2           NaN               NaN             NaN              NaN
# 3           8.0  Alcoholic Drinks            13.0              1.0
# 4           NaN               NaN             NaN              NaN
# ...         ...               ...             ...              ...
# 43331       8.0  Alcoholic Drinks            15.0              1.0
# 43332       NaN               NaN             NaN              NaN
# 43333       8.0  Alcoholic Drinks            15.0              1.0
# 43334       NaN               NaN             NaN              NaN
# 43335       8.0  Alcoholic Drinks            15.0              1.0
#
#           Data_Type       Global_Brand_Owner            Unit  Year_text  \
# 0               NaN                      NaN             NaN        NaN
# 1      Total Volume  Anheuser-Busch InBev NV  million litres     2016.0
# 2               NaN                      NaN             NaN        NaN
# 3      Total Volume              Heineken NV  million litres     2016.0
# 4               NaN                      NaN             NaN        NaN
# ...             ...                      ...             ...        ...
# 43331  Total Volume        Rosspirtprom FGUP      000 litres     2016.0
# 43332           NaN                      NaN             NaN        NaN
# 43333  Total Volume            Private Label      000 litres     2016.0
# 43334           NaN                      NaN             NaN        NaN
# 43335  Total Volume                   Others      000 litres     2016.0
#
#                    Year_date  Year_minus_2016       Volume
# 0                        NaN              NaN          NaN
# 1                   31-12-16              4.0  35506,37732
# 2                        NaN              NaN          NaN
# 3      Saturday, 31 Dec 2016              4.0   18482,5958
# 4                        NaN              NaN          NaN
# ...                      ...              ...          ...
# 43331             31 12 2016              4.0  3,708013795
# 43332                    NaN              NaN          NaN
# 43333               31-12-16              4.0  307,7663666
# 43334                    NaN              NaN          NaN
# 43335              31-Dec-16              4.0  8263,549123
#
# [43336 rows x 11 columns]

# %%
company_share.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43336 entries, 0 to 43335
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Location            21668 non-null  float64
#  1   Industry            21668 non-null  object
#  2   Subcategory_ID      21668 non-null  float64
#  3   Hierarchy_Level     21668 non-null  float64
#  4   Data_Type           21668 non-null  object
#  5   Global_Brand_Owner  21668 non-null  object
#  6   Unit                21668 non-null  object
#  7   Year_text           21668 non-null  float64
#  8   Year_date           21668 non-null  object
#  9   Year_minus_2016     21668 non-null  float64
#  10  Volume              21668 non-null  object
# dtypes: float64(5), object(6)
# memory usage: 3.6+ MB

# %%
company_share = company_share.dropna(axis = 0, how = 'all')
company_share
# Out:
#        Location          Industry  Subcategory_ID  Hierarchy_Level  \
# 1           8.0  Alcoholic Drinks            13.0              1.0
# 3           8.0  Alcoholic Drinks            13.0              1.0
# 5           8.0  Alcoholic Drinks            13.0              1.0
# 7           8.0  Alcoholic Drinks            13.0              1.0
# 9           8.0  Alcoholic Drinks            13.0              1.0
# ...         ...               ...             ...              ...
# 43327       8.0  Alcoholic Drinks            15.0              1.0
# 43329       8.0  Alcoholic Drinks            15.0              1.0
# 43331       8.0  Alcoholic Drinks            15.0              1.0
# 43333       8.0  Alcoholic Drinks            15.0              1.0
# 43335       8.0  Alcoholic Drinks            15.0              1.0
#
#           Data_Type                         Global_Brand_Owner  \
# 1      Total Volume                    Anheuser-Busch InBev NV
# 3      Total Volume                                Heineken NV
# 5      Total Volume                              Carlsberg A/S
# 7      Total Volume                          Dragonyte Brewery
# 9      Total Volume                    Tsingtao Brewery Co Ltd
# ...             ...                                        ...
# 43327  Total Volume  Central European Distribution Corp (CEDC)
# 43329  Total Volume           Hubei Zhijiang Distillery Co Ltd
# 43331  Total Volume                          Rosspirtprom FGUP
# 43333  Total Volume                              Private Label
# 43335  Total Volume                                     Others
#
#                  Unit  Year_text              Year_date  Year_minus_2016  \
# 1      million litres     2016.0               31-12-16              4.0
# 3      million litres     2016.0  Saturday, 31 Dec 2016              4.0
# 5      million litres     2016.0               31-12-16              4.0
# 7      million litres     2016.0              31-Dec-16              4.0
# 9      million litres     2016.0             31 12 2016              4.0
# ...               ...        ...                    ...              ...
# 43327      000 litres     2016.0  Saturday, 31 Dec 2016              4.0
# 43329      000 litres     2016.0             31 12 2016              4.0
# 43331      000 litres     2016.0             31 12 2016              4.0
# 43333      000 litres     2016.0               31-12-16              4.0
# 43335      000 litres     2016.0              31-Dec-16              4.0
#
#             Volume
# 1      35506,37732
# 3       18482,5958
# 5      11121,69868
# 7       6252,38259
# 9      7834,494901
# ...            ...
# 43327  223,0247261
# 43329  78,55588126
# 43331  3,708013795
# 43333  307,7663666
# 43335  8263,549123
#
# [21668 rows x 11 columns]

# %%
company_share['Year_date'].unique()
# Out:
# array(['31-12-16', 'Saturday, 31 Dec 2016', '31-Dec-16', '31 12 2016',
#        'Sat, 31 December 2016', '31-Dec-17', '31 12 2018',
#        'Tuesday, 31 Dec 2019', '31-Dec-20', 'Fri, 31 December 2021',
#        '31 12 2017', '31-12-18', 'Friday, 31 Dec 2021', '31-Dec-19',
#        '31 12 2020', '31 12 2019', 'Thursday, 31 Dec 2020', '31-12-21',
#        '31-12-17', 'Monday, 31 Dec 2018', '31-12-20',
#        'Sunday, 31 Dec 2017', 'Mon, 31 December 2018', '31 12 2021',
#        '31-12-19', 'Thu, 31 December 2020', '31-Dec-21',
#        'Sun, 31 December 2017', 'Tue, 31 December 2019', '31-Dec-18'],
#       dtype=object)

# %%
company_share.isnull().sum()
# Out:
# Location              0
# Industry              0
# Subcategory_ID        0
# Hierarchy_Level       0
# Data_Type             0
# Global_Brand_Owner    0
# Unit                  0
# Year_text             0
# Year_date             0
# Year_minus_2016       0
# Volume                0
# dtype: int64

# %% [markdown]
# MARKET SIZE

# %%
market_size
# Out:
#       Location          Industry  Subcategory  Hierarchy_Level  \
# 0            1  Alcoholic Drinks            1                3
# 1            1  Alcoholic Drinks            1                3
# 2            1  Alcoholic Drinks            1                3
# 3            1  Alcoholic Drinks            1                3
# 4            1  Alcoholic Drinks            1                3
# ...        ...               ...          ...              ...
# 1216         7  Alcoholic Drinks           17                1
# 1217         7  Alcoholic Drinks           17                1
# 1218         7  Alcoholic Drinks           17                1
# 1219         7  Alcoholic Drinks           17                1
# 1220         7  Alcoholic Drinks           17                1
#
#             Data_Type         Unit  \
# 0     Total Value RSP  USD million
# 1     Total Value RSP  USD million
# 2     Total Value RSP  USD million
# 3     Total Value RSP  USD million
# 4     Total Value RSP  USD million
# ...               ...          ...
# 1216  Total Value RSP  USD million
# 1217  Total Value RSP  USD million
# 1218  Total Value RSP  USD million
# 1219  Total Value RSP  USD million
# 1220  Total Value RSP  USD million
#
#                                        Current_Constant  \
# 0     Historic Constant 2021 Prices, Forecast Consta...
# 1     Historic Constant 2021 Prices, Forecast Consta...
# 2     Historic Constant 2021 Prices, Forecast Consta...
# 3     Historic Constant 2021 Prices, Forecast Consta...
# 4     Historic Constant 2021 Prices, Forecast Consta...
# ...                                                 ...
# 1216  Historic Constant 2021 Prices, Forecast Consta...
# 1217  Historic Constant 2021 Prices, Forecast Consta...
# 1218  Historic Constant 2021 Prices, Forecast Consta...
# 1219  Historic Constant 2021 Prices, Forecast Consta...
# 1220  Historic Constant 2021 Prices, Forecast Consta...
#
#                                     Currency_Conversion  Year  Year_date  \
# 0     Historic Fixed 2021 Exchange Rates, Forecast F...  2016  31-Dec-16
# 1     Historic Fixed 2021 Exchange Rates, Forecast F...  2017  31-Dec-17
# 2     Historic Fixed 2021 Exchange Rates, Forecast F...  2018  31-Dec-18
# 3     Historic Fixed 2021 Exchange Rates, Forecast F...  2019  31-Dec-19
# 4     Historic Fixed 2021 Exchange Rates, Forecast F...  2020  31-Dec-20
# ...                                                 ...   ...        ...
# 1216  Historic Fixed 2021 Exchange Rates, Forecast F...  2022  31-Dec-22
# 1217  Historic Fixed 2021 Exchange Rates, Forecast F...  2023  31-Dec-23
# 1218  Historic Fixed 2021 Exchange Rates, Forecast F...  2024  31-Dec-24
# 1219  Historic Fixed 2021 Exchange Rates, Forecast F...  2025  31-Dec-25
# 1220  Historic Fixed 2021 Exchange Rates, Forecast F...  2026  31-Dec-26
#
#           RSP  Volume  Year_minus_2016  Year_minus_2022  Edition
# 0     301.000  27.000                4               -2     2022
# 1     318.000  28.000                5               -1     2022
# 2     458.000  40.000                6                0     2022
# 3     612.000  51.000                7                1     2022
# 4     774.000  62.000                8                2     2022
# ...       ...     ...              ...              ...      ...
# 1216    6.545   1.204               10                4     2022
# 1217    6.628   1.214               11                5     2022
# 1218    6.708   1.227               12                6     2022
# 1219    6.793   1.240               13                7     2022
# 1220    6.892   1.256               14                8     2022
#
# [1221 rows x 15 columns]

# %%
market_size.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1221 entries, 0 to 1220
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Location             1221 non-null   int64
#  1   Industry             1221 non-null   object
#  2   Subcategory          1221 non-null   int64
#  3   Hierarchy_Level      1221 non-null   int64
#  4   Data_Type            1221 non-null   object
#  5   Unit                 1221 non-null   object
#  6   Current_Constant     1221 non-null   object
#  7   Currency_Conversion  1221 non-null   object
#  8   Year                 1221 non-null   int64
#  9   Year_date            1221 non-null   object
#  10  RSP                  1221 non-null   float64
#  11  Volume               1221 non-null   float64
#  12  Year_minus_2016      1221 non-null   int64
#  13  Year_minus_2022      1221 non-null   int64
#  14  Edition              1221 non-null   int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 143.2+ KB

# %%
market_size['Year_date'].unique()
# Out:
# array(['31-Dec-16', '31-Dec-17', '31-Dec-18', '31-Dec-19', '31-Dec-20',
#        '31-Dec-21', '31-Dec-22', '31-Dec-23', '31-Dec-24', '31-Dec-25',
#        '31-Dec-26', '31-Dec-87', '31-Dec-66', '31-Dec-76'], dtype=object)

# %% [markdown]
# SUBCATEGORIES

# %%
subcategories
# Out:
#     id  Category                         Name
# 0    1         1                          Ale
# 1    2         1  Weissbier/Weizen/Wheat Beer
# 2    3         1        Flavoured/Mixed Lager
# 3    4         1               Standard Lager
# 4    5         1                      Sorghum
# 5    6         1                        Stout
# 6    7         1           Non Alcoholic Beer
# 7    8         1                        Lager
# 8    9         1                    Dark Beer
# 9   10         1                Premium Lager
# 10  11         1             Mid-Priced Lager
# 11  12         1                Economy Lager
# 12  13         1                         Beer
# 13  14         2                         Wine
# 14  15         3                      Spirits
# 15  16         4  RTDs/High-Strength Premixes
# 16  17         5                  Cider/Perry
